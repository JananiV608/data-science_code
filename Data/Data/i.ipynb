# %%
# !pip install numpy
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
y_2018 = pd.read_csv("D:\data science\Data\Data\2018.csv")
y_2019 = pd.read_csv("D:\data science\Data\Data\2019.csv")
data = pd.concat([y_2018,y_2019],sort=False)
data
